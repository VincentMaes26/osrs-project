# %% [markdown]
# ## Data scraper for runes

# %%
import requests
import numpy as np
import pandas as pd
import json

# %%
base_URI = "http://services.runescape.com/m=itemdb_oldschool/api/graph/"
r =requests.get(base_URI+"555.json")
json_data = json.loads(r.text)
json_data['daily']
# Out:
# {'1587859200000': 5,
#  '1587945600000': 5,
#  '1588032000000': 5,
#  '1588118400000': 5,
#  '1588204800000': 5,
#  '1588291200000': 5,
#  '1588377600000': 5,
#  '1588464000000': 5,
#  '1588550400000': 5,
#  '1588636800000': 5,
#  '1588723200000': 5,
#  '1588809600000': 5,
#  '1588896000000': 5,
#  '1588982400000': 5,
#  '1589068800000': 5,
#  '1589155200000': 5,
#  '1589241600000': 5,
#  '1589328000000': 5,
#  '1589414400000': 5,
#  '1589500800000': 5,
#  '1589587200000': 5,
#  '1589673600000': 5,
#  '1589760000000': 5,
#  '1589846400000': 5,
#  '1589932800000': 5,
#  '1590019200000': 5,
#  '1590105600000': 5,
#  '1590192000000': 5,
#  '1590278400000': 5,
#  '1590364800000': 5,
#  '1590451200000': 5,
#  '1590537600000': 5,
#  '1590624000000': 5,
#  '1590710400000': 5,
#  '1590796800000': 5,
#  '1590883200000': 5,
#  '1590969600000': 5,
#  '1591056000000': 5,
#  '1591142400000': 5,
#  '1591228800000': 5,
#  '1591315200000': 5,
#  '1591401600000': 5,
#  '1591488000000': 5,
# ...

# %%
runes = np.arange(start=554, stop=567, step=1 )
runeDict = {}

for runeID in runes:
    rune = requests.get(base_URI+str(runeID)+".json")
    rune = json.loads(rune.text)
    runeDict.
